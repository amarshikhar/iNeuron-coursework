# %%
# !kaggle competitions download -c titanic
# Out:
# /bin/bash: kaggle: command not found

# %%
import pandas as pd

# %%
df=pd.read_csv("test.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.dtypes
# Out:
# PassengerId      int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
dy=df.dtypes

# %%
dy["Pclass"]
# Out:
# dtype('int64')

# %%
l=[0,1,2,3,4,5,"shikhs","amar","data science"]

# %%
l[6]
# Out:
# 'shikhs'

# %%
dy[0:4]
# Out:
# PassengerId     int64
# Pclass          int64
# Name           object
# Sex            object
# dtype: object

# %%
dy[0:10:2]
# Out:
# PassengerId      int64
# Name            object
# Age            float64
# Parch            int64
# Fare           float64
# dtype: object

# %%
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df["Age"]
# Out:
# 0      34.5
# 1      47.0
# 2      62.0
# 3      27.0
# 4      22.0
#        ...
# 413     NaN
# 414    39.0
# 415    38.5
# 416     NaN
# 417     NaN
# Name: Age, Length: 418, dtype: float64

# %%
type(df["Age"])
# Out:
# pandas.core.series.Series

# %%
df["Age"][10:100]
# Out:
# 10     NaN
# 11    46.0
# 12    23.0
# 13    63.0
# 14    47.0
#       ...
# 95    25.0
# 96    76.0
# 97    29.0
# 98    20.0
# 99    33.0
# Name: Age, Length: 90, dtype: float64

# %%
df["Age"][::-1]
# Out:
# 417     NaN
# 416     NaN
# 415    38.5
# 414    39.0
# 413     NaN
#        ...
# 4      22.0
# 3      27.0
# 2      62.0
# 1      47.0
# 0      34.5
# Name: Age, Length: 418, dtype: float64

# %%
list(df["Age"][::2])
# Out:
# [34.5,
#  62.0,
#  22.0,
#  30.0,
#  18.0,
#  nan,
#  23.0,
#  47.0,
#  35.0,
#  27.0,
#  55.0,
#  nan,
#  48.0,
#  22.0,
#  41.0,
#  50.0,
#  33.0,
#  30.0,
#  nan,
#  25.0,
#  39.0,
#  41.0,
#  45.0,
#  45.0,
#  60.0,
#  24.0,
#  20.0,
#  nan,
#  35.0,
#  nan,
#  17.0,
#  18.0,
#  13.0,
#  18.0,
#  31.0,
#  24.0,
#  29.0,
#  35.0,
#  nan,
#  30.0,
#  6.0,
#  49.0,
#  nan,
#  27.0,
#  nan,
#  22.0,
#  27.0,
#  25.0,
#  76.0,
#  20.0,
#  43.0,
#  nan,
#  16.0,
#  21.0,
#  nan,
#  41.0,
#  36.0,
#  63.0,
#  nan,
#  36.0,
#  12.0,
#  35.0,
#  nan,
#  22.0,
#  42.0,
#  32.0,
#  nan,
#  43.0,
#  26.5,
#  23.0,
#  10.0,
#  61.0,
#  42.0,
#  nan,
#  nan,
#  23.0,
#  60.5,
#  13.0,
#  29.0,
#  42.0,
#  nan,
#  26.0,
#  41.0,
#  48.0,
#  nan,
#  nan,
#  23.0,
#  40.0,
#  20.0,
#  36.0,
#  30.0,
#  18.0,
#  27.0,
#  21.0,
#  nan,
#  34.0,
#  11.5,
#  8.0,
#  6.0,
#  23.0,
#  nan,
#  47.0,
#  25.0,
#  35.0,
#  33.0,
#  32.0,
#  17.0,
#  38.0,
#  nan,
#  50.0,
#  30.0,
#  22.0,
#  53.0,
# ...

# %%
df.dtypes
# Out:
# PassengerId      int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.describe()#basic statistics data
#only numerical data type column
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
df.dtypes == "object"
# Out:
# PassengerId    False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df.dtypes[df.dtypes == "object"]
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
df_cat=df[df.dtypes[df.dtypes == "object"].index]

# %%
df_cat.describe()
#using describe on categorical data
# Out:
#                     Name   Sex    Ticket            Cabin Embarked
# count                418   418       418               91      418
# unique               418     2       363               76        3
# top     Kelly, Mr. James  male  PC 17608  B57 B59 B63 B66        S
# freq                   1   266         5                3      270

# %%
df.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df[["Name","Fare"]]
# Out:
#                                              Name      Fare
# 0                                Kelly, Mr. James    7.8292
# 1                Wilkes, Mrs. James (Ellen Needs)    7.0000
# 2                       Myles, Mr. Thomas Francis    9.6875
# 3                                Wirz, Mr. Albert    8.6625
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)   12.2875
# ..                                            ...       ...
# 413                            Spector, Mr. Woolf    8.0500
# 414                  Oliva y Ocana, Dona. Fermina  108.9000
# 415                  Saether, Mr. Simon Sivertsen    7.2500
# 416                           Ware, Mr. Frederick    8.0500
# 417                      Peter, Master. Michael J   22.3583
#
# [418 rows x 2 columns]

# %%
type(df[["Name","Fare"]])
# Out:
# pandas.core.frame.DataFrame

# %%
import numpy as np

# %%
df_age_null=np.where(df["Age"].isnull()==True)#index list

# %%
df[df["Age"].isnull()==True]
# Out:
#      PassengerId  Pclass                                               Name  \
# 10           902       3                                   Ilieff, Mr. Ylio
# 22           914       1               Flegenheim, Mrs. Alfred (Antoinette)
# 29           921       3                                  Samaan, Mr. Elias
# 33           925       3  Johnston, Mrs. Andrew G (Elizabeth Lily" Watson)"
# 36           928       3                                Roth, Miss. Sarah A
# ..           ...     ...                                                ...
# 408         1300       3                    Riordan, Miss. Johanna Hannah""
# 410         1302       3                             Naughton, Miss. Hannah
# 413         1305       3                                 Spector, Mr. Woolf
# 416         1308       3                                Ware, Mr. Frederick
# 417         1309       3                           Peter, Master. Michael J
#
# ...

# %%
df_age_null
# Out:
# (array([ 10,  22,  29,  33,  36,  39,  41,  47,  54,  58,  65,  76,  83,
#          84,  85,  88,  91,  93, 102, 107, 108, 111, 116, 121, 124, 127,
#         132, 133, 146, 148, 151, 160, 163, 168, 170, 173, 183, 188, 191,
#         199, 200, 205, 211, 216, 219, 225, 227, 233, 243, 244, 249, 255,
#         256, 265, 266, 267, 268, 271, 273, 274, 282, 286, 288, 289, 290,
#         292, 297, 301, 304, 312, 332, 339, 342, 344, 357, 358, 365, 366,
#         380, 382, 384, 408, 410, 413, 416, 417]),)

# %%
df[["Name","Pclass"]]
# Out:
#                                              Name  Pclass
# 0                                Kelly, Mr. James       3
# 1                Wilkes, Mrs. James (Ellen Needs)       3
# 2                       Myles, Mr. Thomas Francis       2
# 3                                Wirz, Mr. Albert       3
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)       3
# ..                                            ...     ...
# 413                            Spector, Mr. Woolf       3
# 414                  Oliva y Ocana, Dona. Fermina       1
# 415                  Saether, Mr. Simon Sivertsen       3
# 416                           Ware, Mr. Frederick       3
# 417                      Peter, Master. Michael J       3
#
# [418 rows x 2 columns]

# %%
df.iloc[df_age_null]#iloc integer location
# Out:
#      PassengerId  Pclass                                               Name  \
# 10           902       3                                   Ilieff, Mr. Ylio
# 22           914       1               Flegenheim, Mrs. Alfred (Antoinette)
# 29           921       3                                  Samaan, Mr. Elias
# 33           925       3  Johnston, Mrs. Andrew G (Elizabeth Lily" Watson)"
# 36           928       3                                Roth, Miss. Sarah A
# ..           ...     ...                                                ...
# 408         1300       3                    Riordan, Miss. Johanna Hannah""
# 410         1302       3                             Naughton, Miss. Hannah
# 413         1305       3                                 Spector, Mr. Woolf
# 416         1308       3                                Ware, Mr. Frederick
# 417         1309       3                           Peter, Master. Michael J
#
# ...

# %%
df.iloc[10]#dtype is series
# Out:
# PassengerId                 902
# Pclass                        3
# Name           Ilieff, Mr. Ylio
# Sex                        male
# Age                         NaN
# SibSp                         0
# Parch                         0
# Ticket                   349220
# Fare                     7.8958
# Cabin                       NaN
# Embarked                      S
# Name: 10, dtype: object

# %%
df.iloc[[1,2,3,6,7]]#index values input
# Out:
#    PassengerId  Pclass                              Name     Sex   Age  SibSp  \
# 1          893       3  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2          894       2         Myles, Mr. Thomas Francis    male  62.0      0
# 3          895       3                  Wirz, Mr. Albert    male  27.0      0
# 6          898       3              Connolly, Miss. Kate  female  30.0      0
# 7          899       2      Caldwell, Mr. Albert Francis    male  26.0      1
#
#    Parch  Ticket     Fare Cabin Embarked
# 1      0  363272   7.0000   NaN        S
# 2      0  240276   9.6875   NaN        Q
# 3      0  315154   8.6625   NaN        S
# 6      0  330972   7.6292   NaN        Q
# 7      1  248738  29.0000   NaN        S

# %%
df.iloc[np.where(df["Fare"]==max(df["Fare"]))]["Name"]
# Out:
# 343    Cardeza, Mrs. James Warburton Martinez (Charlo...
# Name: Name, dtype: object

# %%
df[df["Fare"]==df["Fare"].max()]["Name"]
# Out:
# 343    Cardeza, Mrs. James Warburton Martinez (Charlo...
# Name: Name, dtype: object

# %%
df[df["Age"]==24.0]["Name"]
# Out:
# 15     del Carlo, Mrs. Sebastiano (Argenia Genovesi)
# 31                     Jefferys, Mr. Clifford Thomas
# 50                          Smith, Mr. Lucien Philip
# 70                         Mulvihill, Miss. Bertha E
# 79                            Doyle, Miss. Elizabeth
# 129                             Petersen, Mr. Marius
# 135                        Carlsson, Mr. Carl Robert
# 155                             Duquemin, Mr. Joseph
# 207                     Collett, Mr. Sidney C Stuart
# 253                         Salander, Mr. Karl Johan
# 287                       Snyder, Mr. John Pillsbury
# 303                                Pokrnic, Mr. Tome
# 348                                 Giles, Mr. Ralph
# 361          Mallet, Mrs. Albert (Antoinette Magnin)
# 385                               Herman, Miss. Kate
# 386                   Aronsson, Mr. Ernst Axel Algot
# 396                             Colbert, Mr. Patrick
# Name: Name, dtype: object

# %%
df[df["Age"]==df["Age"].min()]
# Out:
#      PassengerId  Pclass                                     Name     Sex  \
# 354         1246       3  Dean, Miss. Elizabeth Gladys Millvina""  female
#
#       Age  SibSp  Parch     Ticket    Fare Cabin Embarked
# 354  0.17      1      2  C.A. 2315  20.575   NaN        S

# %%
df["Age"][df["Cabin"].isnull()]
# Out:
# 0      34.5
# 1      47.0
# 2      62.0
# 3      27.0
# 4      22.0
#        ...
# 412    28.0
# 413     NaN
# 415    38.5
# 416     NaN
# 417     NaN
# Name: Age, Length: 327, dtype: float64

# %%
df.iloc[np.where(df["Cabin"].isnull()==True)][["Age","Cabin"]]
# Out:
#       Age Cabin
# 0    34.5   NaN
# 1    47.0   NaN
# 2    62.0   NaN
# 3    27.0   NaN
# 4    22.0   NaN
# ..    ...   ...
# 412  28.0   NaN
# 413   NaN   NaN
# 415  38.5   NaN
# 416   NaN   NaN
# 417   NaN   NaN
#
# [327 rows x 2 columns]

# %%
df.dtypes
# Out:
# PassengerId      int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df[(df["Sex"]=="male") & (df["Cabin"].isnull()==True)]
#sex is male and cabin is null
# Out:
#      PassengerId  Pclass                          Name   Sex   Age  SibSp  \
# 0            892       3              Kelly, Mr. James  male  34.5      0
# 2            894       2     Myles, Mr. Thomas Francis  male  62.0      0
# 3            895       3              Wirz, Mr. Albert  male  27.0      0
# 5            897       3    Svensson, Mr. Johan Cervin  male  14.0      0
# 7            899       2  Caldwell, Mr. Albert Francis  male  26.0      1
# ..           ...     ...                           ...   ...   ...    ...
# 406         1298       2     Ware, Mr. William Jeffery  male  23.0      1
# 413         1305       3            Spector, Mr. Woolf  male   NaN      0
# 415         1307       3  Saether, Mr. Simon Sivertsen  male  38.5      0
# 416         1308       3           Ware, Mr. Frederick  male   NaN      0
# 417         1309       3      Peter, Master. Michael J  male   NaN      1
#
#      Parch              Ticket     Fare Cabin Embarked
# ...

# %%
df["new column"]="shikhs"

# %%
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked new column
# 0  34.5      0      0   330911   7.8292   NaN        Q     shikhs
# 1  47.0      1      0   363272   7.0000   NaN        S     shikhs
# 2  62.0      0      0   240276   9.6875   NaN        Q     shikhs
# 3  27.0      0      0   315154   8.6625   NaN        S     shikhs
# 4  22.0      1      1  3101298  12.2875   NaN        S     shikhs

# %%
l=[1,2,3,4,5]

# %%
pd.Series(l)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
d={"key":'shikhs',"title":"amar","mail_id":"shikhs@gmail.com"}

# %%
d
# Out:
# {'key': 'shikhs', 'title': 'amar', 'mail_id': 'shikhs@gmail.com'}

# %%
pd.DataFrame(d,index=["key","title","mail_id"])
# Out:
#             key title           mail_id
# key      shikhs  amar  shikhs@gmail.com
# title    shikhs  amar  shikhs@gmail.com
# mail_id  shikhs  amar  shikhs@gmail.com

# %%
pd.Series(d)
# Out:
# key                  shikhs
# title                  amar
# mail_id    shikhs@gmail.com
# dtype: object

# %%
arr=np.random.randn(3,4)

# %%
pd.DataFrame(arr)
# Out:
#           0         1         2         3
# 0 -0.438581  0.208212  0.676316 -0.830017
# 1 -0.367358  0.641900  1.043389  0.971235
# 2  1.213043  0.031728  1.313085  0.010470

# %%
pd.Series(arr)
#not support as its multidimensional array
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-104-409226d0ba63> in <module>
# ----> 1 pd.Series(arr)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     325                     data = data.copy()
#     326             else:
# --> 327                 data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#     328
#     329                 data = SingleBlockManager.from_array(data, index)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     494     elif subarr.ndim > 1:
#     495         if isinstance(data, np.ndarray):
# --> 496             raise Exception("Data must be 1-dimensional")
#     497         else:
# ...

# %%
ser=pd.Series(np.array([4,5,6,7,8]),index=["a","b","shikhs","amar","c"])

# %%
ser
# Out:
# a         4
# b         5
# shikhs    6
# amar      7
# c         8
# dtype: int64

# %%
ser["shikhs"]
# Out:
# 6

# %%
ser.loc["shikhs"]#string
# Out:
# 6

# %%
ser.iloc[0]#i for integer access
# Out:
# 4

# %%
ser=pd.Series(np.array([4,5,6,7,8]),index=[12,23,43,45,55])

# %%
ser
# Out:
# 12    4
# 23    5
# 43    6
# 45    7
# 55    8
# dtype: int64

# %%
ser.iloc[0]#iloc takes default index
# Out:
# 4

# %%
ser.loc[55]#loc can acces name index
# Out:
# 8

# %%
df=pd.DataFrame(np.random.randint(3,6,(4,5)),index=["a","b","c","d"],columns=["x","y","z","u","v"])

# %%
df
# Out:
#    x  y  z  u  v
# a  5  3  3  4  4
# b  4  5  4  4  4
# c  5  5  5  4  3
# d  5  5  5  3  5

# %%
df.iloc[2:4,2:4]
# Out:
#    z  u
# c  5  4
# d  5  3

# %%
df.loc[["c","d"],["z","u"]]
# Out:
#    z  u
# c  5  4
# d  5  3

# %%
df.iloc[[2,3],[2,3]]
# Out:
#    z  u
# c  5  4
# d  5  3

# %%
df
# Out:
#    x  y  z  u  v
# a  5  3  3  4  4
# b  4  5  4  4  4
# c  5  5  5  4  3
# d  5  5  5  3  5

# %%
df["new"]=df["x"]+df.y

# %%
df
# Out:
#    x  y  z  u  v  new
# a  5  3  3  4  4    8
# b  4  5  4  4  4    9
# c  5  5  5  4  3   10
# d  5  5  5  3  5   10

# %%
df.drop("x",axis=1,inplace=True)

# %%
df
# Out:
#    y  z  u  v  new
# a  3  3  4  4    8
# b  5  4  4  4    9
# c  5  5  4  3   10
# d  5  5  3  5   10

# %%
df.drop("a",inplace=True)

# %%
df
# Out:
#    y  z  u  v  new
# b  5  4  4  4    9
# c  5  5  4  3   10
# d  5  5  3  5   10

# %%
df=df.drop("c")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-153-b8628bfe8811> in <module>
# ----> 1 df=df.drop("c")
#
# AttributeError: 'NoneType' object has no attribute 'drop'

# %%
df

# %%
np.random.seed(23)
df=pd.DataFrame(np.random.randn(4,5),index=["a","b","c","d"],columns=["x","y","z","u","v"])

# %%
df
# Out:
#           x         y         z         u         v
# a  0.666988  0.025813 -0.777619  0.948634  0.701672
# b -1.051082 -0.367548 -1.137460 -1.322148  1.772258
# c -0.347459  0.670140  0.322272  0.060343 -1.043450
# d -1.009942  0.441736  1.128877 -1.838068 -0.938769

# %%
df.values[df.values<0]
# Out:
# array([-0.77761941, -1.05108156, -0.36754812, -1.13745969, -1.32214752,
#        -0.34745899, -1.04345   , -1.00994188, -1.83806777, -0.93876863])

# %%
df.values[df.values<0]
# Out:
# array([-0.77761941, -1.05108156, -0.36754812, -1.13745969, -1.32214752,
#        -0.34745899, -1.04345   , -1.00994188, -1.83806777, -0.93876863])

# %%
l=df.values[df<0]
for i in df.columns:
    for j in df.index:
        if df[i][j] in l:
            print(i,j,df[i][j])
# Out:
# x b -1.0510815639071178
# x c -0.34745899102186334
# x d -1.0099418765878465
# y b -0.3675481161171661
# z a -0.7776194131918178
# z b -1.1374596907250272
# u b -1.3221475225908594
# u d -1.8380677677579502
# v c -1.0434500017467254
# v d -0.9387686311201282

# %%
df.values[df<0]
# Out:
# array([-0.77761941, -1.05108156, -0.36754812, -1.13745969, -1.32214752,
#        -0.34745899, -1.04345   , -1.00994188, -1.83806777, -0.93876863])

# %%
d={"key1":[1,2,3,4,np.nan],"key2":["shikhs","amar",np.nan,5,6],"key3":[np.nan,np.nan,np.nan,3,2]}
df=pd.DataFrame(d)

# %%
df
# Out:
#    key1    key2  key3
# 0   1.0  shikhs   NaN
# 1   2.0    amar   NaN
# 2   3.0     NaN   NaN
# 3   4.0       5   3.0
# 4   NaN       6   2.0

# %%
df.dropna()#axis=0:rows
# Out:
#    key1 key2  key3
# 3   4.0    5   3.0

# %%
df.dropna(axis=1)#columns
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
df.dropna(thresh=1)
#requires that many non nan value across rows
#axis=0
# Out:
#    key1    key2  key3
# 0   1.0  shikhs   NaN
# 1   2.0    amar   NaN
# 2   3.0     NaN   NaN
# 3   4.0       5   3.0
# 4   NaN       6   2.0

# %%
df.dropna(thresh=2)
#requires at least 2 non nan value across rows
#drops 2
# Out:
#    key1    key2  key3
# 0   1.0  shikhs   NaN
# 1   2.0    amar   NaN
# 3   4.0       5   3.0
# 4   NaN       6   2.0

# %%
df.dropna(thresh=3)
# Out:
#    key1 key2  key3
# 3   4.0    5   3.0

# %%
df.dropna(axis=1,thresh=3)
# Out:
#    key1    key2
# 0   1.0  shikhs
# 1   2.0    amar
# 2   3.0     NaN
# 3   4.0       5
# 4   NaN       6

# %%
df.fillna("shikhs")
# Out:
#      key1    key2    key3
# 0       1  shikhs  shikhs
# 1       2    amar  shikhs
# 2       3  shikhs  shikhs
# 3       4       5       3
# 4  shikhs       6       2

# %%
df.fillna(12)
# Out:
#    key1    key2  key3
# 0   1.0  shikhs  12.0
# 1   2.0    amar  12.0
# 2   3.0      12  12.0
# 3   4.0       5   3.0
# 4  12.0       6   2.0

# %%
df.fillna(value=df["key1"].mean())
# Out:
#    key1    key2  key3
# 0   1.0  shikhs   2.5
# 1   2.0    amar   2.5
# 2   3.0     2.5   2.5
# 3   4.0       5   3.0
# 4   2.5       6   2.0

# %%
df["key1"].fillna(value=df["key1"].mean())
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    2.5
# Name: key1, dtype: float64

# %%
d1={
    "name":["shikhs","sudh","sami","anuj","kris"],"mail_id":["shikhs@gmail.com","sudh@hotmail.com","sami@gmail.com","anuj@yahoo.com","kris@gmail.com"],"key3":[100,200,100,500,200]
}
df=pd.DataFrame(d1)

# %%
df
# Out:
#      name           mail_id  key3
# 0  shikhs  shikhs@gmail.com   100
# 1    sudh  sudh@hotmail.com   200
# 2    sami    sami@gmail.com   100
# 3    anuj    anuj@yahoo.com   500
# 4    kris    kris@gmail.com   200

# %%
df.groupby("mail_id").sum()
# Out:
#                   key3
# mail_id
# anuj@yahoo.com     500
# kris@gmail.com     200
# sami@gmail.com     100
# shikhs@gmail.com   100
# sudh@hotmail.com   200

# %%
df.groupby("mail_id").describe()
# Out:
#                   key3
#                  count   mean std    min    25%    50%    75%    max
# mail_id
# anuj@yahoo.com     1.0  500.0 NaN  500.0  500.0  500.0  500.0  500.0
# kris@gmail.com     1.0  200.0 NaN  200.0  200.0  200.0  200.0  200.0
# sami@gmail.com     1.0  100.0 NaN  100.0  100.0  100.0  100.0  100.0
# shikhs@gmail.com   1.0  100.0 NaN  100.0  100.0  100.0  100.0  100.0
# sudh@hotmail.com   1.0  200.0 NaN  200.0  200.0  200.0  200.0  200.0

# %%
type(df.groupby("mail_id").describe())
# Out:
# pandas.core.frame.DataFrame

# %%
df.groupby("mail_id").describe().loc["kris@gmail.com"]
# Out:
# key3  count      1.0
#       mean     200.0
#       std        NaN
#       min      200.0
#       25%      200.0
#       50%      200.0
#       75%      200.0
#       max      200.0
# Name: kris@gmail.com, dtype: float64

# %%
df.groupby("mail_id").describe().loc["kris@gmail.com"]["key3"]["mean"]
# Out:
# 200.0

# %%
df.groupby("mail_id").describe().T
#transpose column to row and vice versa
# Out:
# mail_id     anuj@yahoo.com  kris@gmail.com  sami@gmail.com  shikhs@gmail.com  \
# key3 count             1.0             1.0             1.0               1.0
#      mean            500.0           200.0           100.0             100.0
#      std               NaN             NaN             NaN               NaN
#      min             500.0           200.0           100.0             100.0
#      25%             500.0           200.0           100.0             100.0
#      50%             500.0           200.0           100.0             100.0
#      75%             500.0           200.0           100.0             100.0
#      max             500.0           200.0           100.0             100.0
#
# mail_id     sudh@hotmail.com
# key3 count               1.0
#      mean              200.0
#      std                 NaN
#      min               200.0
#      25%               200.0
#      50%               200.0
#      75%               200.0
#      max               200.0

# %%
arr1=np.random.randn(3,4)

# %%
arr2=np.random.randn(3,4)

# %%
arr3=np.random.randn(3,4)

# %%
df1=pd.DataFrame(arr1,columns=["A","B","C","D"],index=[0,1,2])

# %%
df2=pd.DataFrame(arr2,columns=["A","B","C","D"],index=[0,1,2])

# %%
df3=pd.DataFrame(arr3,columns=["A","B","C","D"],index=[0,1,2])

# %%
df1
# Out:
#           A         B         C         D
# 0  0.728876  1.968435 -0.547788 -0.679418
# 1 -2.506230  0.146960  0.606195 -0.022539
# 2  0.013422  0.935945  0.420623  0.411620

# %%
df2
# Out:
#           A         B         C         D
# 0 -0.071324 -0.045438  1.040886 -0.094035
# 1 -0.420844 -0.551989 -0.121098  0.190141
# 2  0.512137  0.131538 -0.331617 -1.632386

# %%
df3
# Out:
#           A         B         C         D
# 0 -1.080565  0.010229  0.437830  1.327788
# 1 -0.251145  1.593111  0.170818 -0.709254
# 2 -0.133025 -0.017357 -0.101093 -0.564040

# %%
df4=pd.concat([df1,df2,df3])
#axis=0: row wise concatenation operation

# %%
df5=pd.concat([df1,df2,df3],axis=1)
#axis=1: column wise concatenation operation

# %%
df4
# Out:
#           A         B         C         D
# 0  0.728876  1.968435 -0.547788 -0.679418
# 1 -2.506230  0.146960  0.606195 -0.022539
# 2  0.013422  0.935945  0.420623  0.411620
# 0 -0.071324 -0.045438  1.040886 -0.094035
# 1 -0.420844 -0.551989 -0.121098  0.190141
# 2  0.512137  0.131538 -0.331617 -1.632386
# 0 -1.080565  0.010229  0.437830  1.327788
# 1 -0.251145  1.593111  0.170818 -0.709254
# 2 -0.133025 -0.017357 -0.101093 -0.564040

# %%
df4.iloc[0]
# Out:
# A    0.728876
# B    1.968435
# C   -0.547788
# D   -0.679418
# Name: 0, dtype: float64

# %%
df4.loc[0]
# Out:
#           A         B         C         D
# 0  0.728876  1.968435 -0.547788 -0.679418
# 0 -0.071324 -0.045438  1.040886 -0.094035
# 0 -1.080565  0.010229  0.437830  1.327788

# %%
df5
# Out:
#           A         B         C         D         A         B         C  \
# 0  0.728876  1.968435 -0.547788 -0.679418 -0.071324 -0.045438  1.040886
# 1 -2.506230  0.146960  0.606195 -0.022539 -0.420844 -0.551989 -0.121098
# 2  0.013422  0.935945  0.420623  0.411620  0.512137  0.131538 -0.331617
#
#           D         A         B         C         D
# 0 -0.094035 -1.080565  0.010229  0.437830  1.327788
# 1  0.190141 -0.251145  1.593111  0.170818 -0.709254
# 2 -1.632386 -0.133025 -0.017357 -0.101093 -0.564040

# %%
df5["A"]
# Out:
#           A         A         A
# 0  0.728876 -0.071324 -1.080565
# 1 -2.506230 -0.420844 -0.251145
# 2  0.013422  0.512137 -0.133025

# %%
df5.iloc[:,4]#all rows and 4 column return
# Out:
# 0   -0.071324
# 1   -0.420844
# 2    0.512137
# Name: A, dtype: float64

# %%
pd.concat([df1,df2,df3],axis=0)
# Out:
#           A         B         C         D
# 0  0.728876  1.968435 -0.547788 -0.679418
# 1 -2.506230  0.146960  0.606195 -0.022539
# 2  0.013422  0.935945  0.420623  0.411620
# 0 -0.071324 -0.045438  1.040886 -0.094035
# 1 -0.420844 -0.551989 -0.121098  0.190141
# 2  0.512137  0.131538 -0.331617 -1.632386
# 0 -1.080565  0.010229  0.437830  1.327788
# 1 -0.251145  1.593111  0.170818 -0.709254
# 2 -0.133025 -0.017357 -0.101093 -0.564040

# %%
df3
# Out:
#           A         B         C         D
# 0 -1.080565  0.010229  0.437830  1.327788
# 1 -0.251145  1.593111  0.170818 -0.709254
# 2 -0.133025 -0.017357 -0.101093 -0.564040

# %%
np.random.seed(23)
arr1=np.random.randn(3,4)
np.random.seed(23)
arr2=np.random.randn(3,4)
df1=pd.DataFrame(arr1,columns=["A","B","C","D"],index=[0,1,2])
df2=pd.DataFrame(arr2,columns=["A","B","C","D"],index=[0,1,2])

# %%
df1
# Out:
#           A         B         C         D
# 0  0.666988  0.025813 -0.777619  0.948634
# 1  0.701672 -1.051082 -0.367548 -1.137460
# 2 -1.322148  1.772258 -0.347459  0.670140

# %%
df2
# Out:
#           A         B         C         D
# 0  0.666988  0.025813 -0.777619  0.948634
# 1  0.701672 -1.051082 -0.367548 -1.137460
# 2 -1.322148  1.772258 -0.347459  0.670140

# %%
pd.merge(df1,df2,on="A")
#if same value of A then merged
# Out:
#           A       B_x       C_x       D_x       B_y       C_y       D_y
# 0  0.666988  0.025813 -0.777619  0.948634  0.025813 -0.777619  0.948634
# 1  0.701672 -1.051082 -0.367548 -1.137460 -1.051082 -0.367548 -1.137460
# 2 -1.322148  1.772258 -0.347459  0.670140  1.772258 -0.347459  0.670140

# %%
#merge, right, left, outer on=["key1"],is based on column

# %%
#join is based on index,df1.join(df2)
#how="right"

# %%
df=pd.DataFrame(np.random.randn(10,4),index=pd.date_range('2021-07-18',periods=10),columns=['a','b','c','d'])

# %%
df
# Out:
#                    a         b         c         d
# 2021-07-18 -1.324548 -0.621920  1.138136  0.302542
# 2021-07-19 -0.851536 -0.046450 -0.024273  0.755376
# 2021-07-20 -0.860614 -0.258632 -0.126106  0.367315
# 2021-07-21 -0.211804 -1.465502 -1.305861  1.231087
# 2021-07-22 -0.472681  0.117045  0.038957  0.389930
# 2021-07-23  1.375974  0.053024  0.811950  0.530399
# 2021-07-24  0.278620 -1.089894 -0.430625  0.948425
# 2021-07-25 -0.297508 -0.333986 -0.263938 -1.191042
# 2021-07-26 -0.811582  0.211131 -0.872256 -1.262511
# 2021-07-27  0.729460  0.828560 -0.055784 -0.992063

# %%
df["new"]=df["c"]+df["d"]

# %%
df
# Out:
#                    a         b         c         d       new
# 2021-07-18 -1.324548 -0.621920  1.138136  0.302542  1.440678
# 2021-07-19 -0.851536 -0.046450 -0.024273  0.755376  0.731103
# 2021-07-20 -0.860614 -0.258632 -0.126106  0.367315  0.241209
# 2021-07-21 -0.211804 -1.465502 -1.305861  1.231087 -0.074774
# 2021-07-22 -0.472681  0.117045  0.038957  0.389930  0.428886
# 2021-07-23  1.375974  0.053024  0.811950  0.530399  1.342349
# 2021-07-24  0.278620 -1.089894 -0.430625  0.948425  0.517800
# 2021-07-25 -0.297508 -0.333986 -0.263938 -1.191042 -1.454980
# 2021-07-26 -0.811582  0.211131 -0.872256 -1.262511 -2.134767
# 2021-07-27  0.729460  0.828560 -0.055784 -0.992063 -1.047847

# %%
df['new_col_square_d']=df["d"].apply(lambda x:x**2)

# %%
df
# Out:
#                    a         b         c         d       new  new_col_square_d
# 2021-07-18 -1.324548 -0.621920  1.138136  0.302542  1.440678          0.091532
# 2021-07-19 -0.851536 -0.046450 -0.024273  0.755376  0.731103          0.570593
# 2021-07-20 -0.860614 -0.258632 -0.126106  0.367315  0.241209          0.134920
# 2021-07-21 -0.211804 -1.465502 -1.305861  1.231087 -0.074774          1.515576
# 2021-07-22 -0.472681  0.117045  0.038957  0.389930  0.428886          0.152045
# 2021-07-23  1.375974  0.053024  0.811950  0.530399  1.342349          0.281323
# 2021-07-24  0.278620 -1.089894 -0.430625  0.948425  0.517800          0.899510
# 2021-07-25 -0.297508 -0.333986 -0.263938 -1.191042 -1.454980          1.418581
# 2021-07-26 -0.811582  0.211131 -0.872256 -1.262511 -2.134767          1.593934
# 2021-07-27  0.729460  0.828560 -0.055784 -0.992063 -1.047847          0.984189

# %%
df['new_col_square_d_log']=df["d"].apply(lambda x:np.log(x))

# %%
df
# Out:
#                    a         b         c         d       new  \
# 2021-07-18 -1.324548 -0.621920  1.138136  0.302542  1.440678
# 2021-07-19 -0.851536 -0.046450 -0.024273  0.755376  0.731103
# 2021-07-20 -0.860614 -0.258632 -0.126106  0.367315  0.241209
# 2021-07-21 -0.211804 -1.465502 -1.305861  1.231087 -0.074774
# 2021-07-22 -0.472681  0.117045  0.038957  0.389930  0.428886
# 2021-07-23  1.375974  0.053024  0.811950  0.530399  1.342349
# 2021-07-24  0.278620 -1.089894 -0.430625  0.948425  0.517800
# 2021-07-25 -0.297508 -0.333986 -0.263938 -1.191042 -1.454980
# 2021-07-26 -0.811582  0.211131 -0.872256 -1.262511 -2.134767
# 2021-07-27  0.729460  0.828560 -0.055784 -0.992063 -1.047847
#
#             new_col_square_d  new_col_square_d_log
# 2021-07-18          0.091532             -1.195535
# 2021-07-19          0.570593             -0.280540
# 2021-07-20          0.134920             -1.001536
# 2021-07-21          1.515576              0.207898
# ...

# %%
def test(x):
    if (x<0):
        return x
    else:
        return np.log(x)

# %%
df['new_col_square_d_log_1']=df["d"].apply(test)

# %%
df
# Out:
#                    a         b         c         d       new  \
# 2021-07-18 -1.324548 -0.621920  1.138136  0.302542  1.440678
# 2021-07-19 -0.851536 -0.046450 -0.024273  0.755376  0.731103
# 2021-07-20 -0.860614 -0.258632 -0.126106  0.367315  0.241209
# 2021-07-21 -0.211804 -1.465502 -1.305861  1.231087 -0.074774
# 2021-07-22 -0.472681  0.117045  0.038957  0.389930  0.428886
# 2021-07-23  1.375974  0.053024  0.811950  0.530399  1.342349
# 2021-07-24  0.278620 -1.089894 -0.430625  0.948425  0.517800
# 2021-07-25 -0.297508 -0.333986 -0.263938 -1.191042 -1.454980
# 2021-07-26 -0.811582  0.211131 -0.872256 -1.262511 -2.134767
# 2021-07-27  0.729460  0.828560 -0.055784 -0.992063 -1.047847
#
#             new_col_square_d  new_col_square_d_log  new_col_square_d_log_1
# 2021-07-18          0.091532             -1.195535               -1.195535
# 2021-07-19          0.570593             -0.280540               -0.280540
# ...

# %%
def test1(x):
    if x<0:
        return 0
    else:
        return 1

# %%
df['new_a']=df["a"].apply(test1)

# %%
df
# Out:
#                    a         b         c         d       new  \
# 2021-07-18 -1.324548 -0.621920  1.138136  0.302542  1.440678
# 2021-07-19 -0.851536 -0.046450 -0.024273  0.755376  0.731103
# 2021-07-20 -0.860614 -0.258632 -0.126106  0.367315  0.241209
# 2021-07-21 -0.211804 -1.465502 -1.305861  1.231087 -0.074774
# 2021-07-22 -0.472681  0.117045  0.038957  0.389930  0.428886
# 2021-07-23  1.375974  0.053024  0.811950  0.530399  1.342349
# 2021-07-24  0.278620 -1.089894 -0.430625  0.948425  0.517800
# 2021-07-25 -0.297508 -0.333986 -0.263938 -1.191042 -1.454980
# 2021-07-26 -0.811582  0.211131 -0.872256 -1.262511 -2.134767
# 2021-07-27  0.729460  0.828560 -0.055784 -0.992063 -1.047847
#
#             new_col_square_d  new_col_square_d_log  new_col_square_d_log_1  \
# 2021-07-18          0.091532             -1.195535               -1.195535
# 2021-07-19          0.570593             -0.280540               -0.280540
# ...

# %%
df.sort_values(by="b")
# Out:
#                    a         b         c         d       new  \
# 2021-07-21 -0.211804 -1.465502 -1.305861  1.231087 -0.074774
# 2021-07-24  0.278620 -1.089894 -0.430625  0.948425  0.517800
# 2021-07-18 -1.324548 -0.621920  1.138136  0.302542  1.440678
# 2021-07-25 -0.297508 -0.333986 -0.263938 -1.191042 -1.454980
# 2021-07-20 -0.860614 -0.258632 -0.126106  0.367315  0.241209
# 2021-07-19 -0.851536 -0.046450 -0.024273  0.755376  0.731103
# 2021-07-23  1.375974  0.053024  0.811950  0.530399  1.342349
# 2021-07-22 -0.472681  0.117045  0.038957  0.389930  0.428886
# 2021-07-26 -0.811582  0.211131 -0.872256 -1.262511 -2.134767
# 2021-07-27  0.729460  0.828560 -0.055784 -0.992063 -1.047847
#
#             new_col_square_d  new_col_square_d_log  new_col_square_d_log_1  \
# 2021-07-21          1.515576              0.207898                0.207898
# 2021-07-24          0.899510             -0.052952               -0.052952
# ...

# %%
df.index
# Out:
# DatetimeIndex(['2021-07-18', '2021-07-19', '2021-07-20', '2021-07-21',
#                '2021-07-22', '2021-07-23', '2021-07-24', '2021-07-25',
#                '2021-07-26', '2021-07-27'],
#               dtype='datetime64[ns]', freq='D')

# %%
df["new_date"]=df.index

# %%
df
# Out:
#                    a         b         c         d       new  \
# 2021-07-18 -1.324548 -0.621920  1.138136  0.302542  1.440678
# 2021-07-19 -0.851536 -0.046450 -0.024273  0.755376  0.731103
# 2021-07-20 -0.860614 -0.258632 -0.126106  0.367315  0.241209
# 2021-07-21 -0.211804 -1.465502 -1.305861  1.231087 -0.074774
# 2021-07-22 -0.472681  0.117045  0.038957  0.389930  0.428886
# 2021-07-23  1.375974  0.053024  0.811950  0.530399  1.342349
# 2021-07-24  0.278620 -1.089894 -0.430625  0.948425  0.517800
# 2021-07-25 -0.297508 -0.333986 -0.263938 -1.191042 -1.454980
# 2021-07-26 -0.811582  0.211131 -0.872256 -1.262511 -2.134767
# 2021-07-27  0.729460  0.828560 -0.055784 -0.992063 -1.047847
#
#             new_col_square_d  new_col_square_d_log  new_col_square_d_log_1  \
# 2021-07-18          0.091532             -1.195535               -1.195535
# 2021-07-19          0.570593             -0.280540               -0.280540
# ...

# %%
df.dtypes
# Out:
# a                                float64
# b                                float64
# c                                float64
# d                                float64
# new                              float64
# new_col_square_d                 float64
# new_col_square_d_log             float64
# new_col_square_d_log_1           float64
# new_a                              int64
# new_date                  datetime64[ns]
# dtype: object

# %%
df["day"]=df.index.day
df["month"]=df.index.month
df["year"]=df.index.year

# %%
df
# Out:
#                    a         b         c         d       new  \
# 2021-07-18 -1.324548 -0.621920  1.138136  0.302542  1.440678
# 2021-07-19 -0.851536 -0.046450 -0.024273  0.755376  0.731103
# 2021-07-20 -0.860614 -0.258632 -0.126106  0.367315  0.241209
# 2021-07-21 -0.211804 -1.465502 -1.305861  1.231087 -0.074774
# 2021-07-22 -0.472681  0.117045  0.038957  0.389930  0.428886
# 2021-07-23  1.375974  0.053024  0.811950  0.530399  1.342349
# 2021-07-24  0.278620 -1.089894 -0.430625  0.948425  0.517800
# 2021-07-25 -0.297508 -0.333986 -0.263938 -1.191042 -1.454980
# 2021-07-26 -0.811582  0.211131 -0.872256 -1.262511 -2.134767
# 2021-07-27  0.729460  0.828560 -0.055784 -0.992063 -1.047847
#
#             new_col_square_d  new_col_square_d_log  new_col_square_d_log_1  \
# 2021-07-18          0.091532             -1.195535               -1.195535
# 2021-07-19          0.570593             -0.280540               -0.280540
# ...

# %%
df["new_col_dayname"]=df.index.day_name()

# %%
df
# Out:
#                    a         b         c         d       new  \
# 2021-07-18 -1.324548 -0.621920  1.138136  0.302542  1.440678
# 2021-07-19 -0.851536 -0.046450 -0.024273  0.755376  0.731103
# 2021-07-20 -0.860614 -0.258632 -0.126106  0.367315  0.241209
# 2021-07-21 -0.211804 -1.465502 -1.305861  1.231087 -0.074774
# 2021-07-22 -0.472681  0.117045  0.038957  0.389930  0.428886
# 2021-07-23  1.375974  0.053024  0.811950  0.530399  1.342349
# 2021-07-24  0.278620 -1.089894 -0.430625  0.948425  0.517800
# 2021-07-25 -0.297508 -0.333986 -0.263938 -1.191042 -1.454980
# 2021-07-26 -0.811582  0.211131 -0.872256 -1.262511 -2.134767
# 2021-07-27  0.729460  0.828560 -0.055784 -0.992063 -1.047847
#
#             new_col_square_d  new_col_square_d_log  new_col_square_d_log_1  \
# 2021-07-18          0.091532             -1.195535               -1.195535
# 2021-07-19          0.570593             -0.280540               -0.280540
# ...

# %%
df.groupby(by="new_col_dayname").count()
# Out:
#                  a  b  c  d  new  new_col_square_d  new_col_square_d_log  \
# new_col_dayname
# Friday           1  1  1  1    1                 1                     1
# Monday           2  2  2  2    2                 2                     1
# Saturday         1  1  1  1    1                 1                     1
# Sunday           2  2  2  2    2                 2                     1
# Thursday         1  1  1  1    1                 1                     1
# Tuesday          2  2  2  2    2                 2                     1
# Wednesday        1  1  1  1    1                 1                     1
#
#                  new_col_square_d_log_1  new_a  new_date  day  month  year
# new_col_dayname
# Friday                                1      1         1    1      1     1
# Monday                                2      2         2    2      2     2
# Saturday                              1      1         1    1      1     1
# ...
